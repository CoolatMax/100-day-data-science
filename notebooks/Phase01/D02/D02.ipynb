# %% [markdown]
# # Understand Python's core data types (int, float, str, bool), variable assignment, and basic arithmetic. Apply to energy units (MW, MWh, €/MWh).

# %% [markdown]
# ## Write a script that converts wind farm power output: given capacity (MW) and capacity factor (%), calculate energy in MWh. Store results in a dictionary.

# %% [markdown]
# ## Python script 'wind_farm_calculator.py' on GitHub. LinkedIn post showing conversion calculations for a real EU wind farm.
